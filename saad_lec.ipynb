# %% [markdown]
# <a href="https://colab.research.google.com/github/saqqad00-pixel/python-learning-journey/blob/main/saad_lec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/data - Sheet1 (2).csv")
data
# Out:
#       id  Education  JoiningYear   City  Age  Gender  salary  Experience  \
# 0   8675  Bachelors         2017  Amman   34    Male   500.0         0.0
# 1   1531  Bachelors         2013  Irbid   28  Female   560.0         3.0
# 2   3028        PHD         2014  Irbid   38  Female  1000.0         2.0
# 3   2203    Masters         2016  Irbid   27  Female   800.0         5.0
# 4   4848    Masters         2017  Amman   24    Male   800.0         2.0
# 5   6877  Bachelors         2016  Amman   22    Male   550.0         0.0
# 6   2012  Bachelors         2015  Irbid   38    Male   550.0         0.0
# 7   8886  Bachelors         2016  Aqaba   34  Female   550.0         2.0
# 8   8741  Bachelors         2016  Amman   23    Male   550.0         1.0
# 9   6789    Masters         2017  Amman   37    Male   900.0         2.0
# 10  9872    Masters         2012  Amman   27    Male   800.0         5.0
# 11  2017  Bachelors         2016  Amman   34    Male   700.0         3.0
# ...

# %%
data.shape
# Out:
# (22, 10)

# %%
data.dtypes
# Out:
# id               int64
# Education       object
# JoiningYear      int64
# City            object
# Age              int64
# Gender          object
# salary         float64
# Experience     float64
# LeaveOrNot      object
# dtype: object

# %%
data.empty
# Out:
# False

# %%
data.head(3)
# Out:
#      id  Education  JoiningYear   City  Age  Gender  salary  Experience  \
# 0  8675  Bachelors         2017  Amman   34    Male   500.0         0.0
# 1  1531  Bachelors         2013  Irbid   28  Female   560.0         3.0
# 2  3028        PHD         2014  Irbid   38  Female  1000.0         2.0
#
#   LeaveOrNot
# 0        yes
# 1         no
# 2         no

# %%
data.head(19)
# Out:
#       id  Education  JoiningYear   City  Age  Gender  salary  Experience  \
# 0   8675  Bachelors         2017  Amman   34    Male   500.0         0.0
# 1   1531  Bachelors         2013  Irbid   28  Female   560.0         3.0
# 2   3028        PHD         2014  Irbid   38  Female  1000.0         2.0
# 3   2203    Masters         2016  Irbid   27  Female   800.0         5.0
# 4   4848    Masters         2017  Amman   24    Male   800.0         2.0
# 5   6877  Bachelors         2016  Amman   22    Male   550.0         0.0
# 6   2012  Bachelors         2015  Irbid   38    Male   550.0         0.0
# 7   8886  Bachelors         2016  Aqaba   34  Female   550.0         2.0
# 8   8741  Bachelors         2016  Amman   23    Male   550.0         1.0
# 9   6789    Masters         2017  Amman   37    Male   900.0         2.0
# 10  9872    Masters         2012  Amman   27    Male   800.0         5.0
# 11  2017  Bachelors         2016  Amman   34    Male   700.0         3.0
# ...

# %%
data.head(1)
# Out:
#      id  Education  JoiningYear   City  Age Gender  salary  Experience  \
# 0  8675  Bachelors         2017  Amman   34   Male   500.0         0.0
#
#   LeaveOrNot
# 0        yes

# %%
data['City']
# Out:
# 0     Amman
# 1     Irbid
# 2     Irbid
# 3     Irbid
# 4     Amman
# 5     Amman
# 6     Irbid
# 7     Aqaba
# 8     Amman
# 9     Amman
# 10    Amman
# 11    Amman
# 12    Irbid
# 13    Aqaba
# 14    Irbid
# 15    Irbid
# 16    Amman
# 17    Amman
# 18    Amman
# 19    Amman
# 20    Amman
# 21    Amman
# Name: City, dtype: object

# %%
data['Age']
# Out:
# 0     34
# 1     28
# 2     38
# 3     27
# 4     24
# 5     22
# 6     38
# 7     34
# 8     23
# 9     37
# 10    27
# 11    34
# 12    32
# 13    39
# 14    37
# 15    29
# 16    34
# 17    34
# 18    30
# 19    30
# 20    30
# 21    30
# Name: Age, dtype: int64

# %%
data[data["City"]=="Irbid"]
# Out:
#       id  Education  JoiningYear   City  Age  Gender  salary  Experience  \
# 1   1531  Bachelors         2013  Irbid   28  Female   560.0         3.0
# 2   3028        PHD         2014  Irbid   38  Female  1000.0         2.0
# 3   2203    Masters         2016  Irbid   27  Female   800.0         5.0
# 6   2012  Bachelors         2015  Irbid   38    Male   550.0         0.0
# 12  3018        PHD         2018  Irbid   32    Male  1500.0         5.0
# 14  6845  Bachelors         2012  Irbid   37    Male     NaN         NaN
# 15  4245  Bachelors         2017  Irbid   29  Female   500.0         3.0
#
#    LeaveOrNot
# 1          no
# 2          no
# 3         NaN
# 6          no
# 12         no
# 14        yes
# 15         no

# %%
data.isnull().sum()
# Out:
# id             0
# Education      0
# JoiningYear    0
# City           0
# Age            0
# Gender         0
# salary         1
# Experience     1
# LeaveOrNot     1
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# np.int64(3)

# %%
data['new_column']=6
data
# Out:
#       id  Education  JoiningYear   City  Age  Gender  salary  Experience  \
# 0   8675  Bachelors         2017  Amman   34    Male   500.0         0.0
# 1   1531  Bachelors         2013  Irbid   28  Female   560.0         3.0
# 2   3028        PHD         2014  Irbid   38  Female  1000.0         2.0
# 3   2203    Masters         2016  Irbid   27  Female   800.0         5.0
# 4   4848    Masters         2017  Amman   24    Male   800.0         2.0
# 5   6877  Bachelors         2016  Amman   22    Male   550.0         0.0
# 6   2012  Bachelors         2015  Irbid   38    Male   550.0         0.0
# 7   8886  Bachelors         2016  Aqaba   34  Female   550.0         2.0
# 8   8741  Bachelors         2016  Amman   23    Male   550.0         1.0
# 9   6789    Masters         2017  Amman   37    Male   900.0         2.0
# 10  9872    Masters         2012  Amman   27    Male   800.0         5.0
# 11  2017  Bachelors         2016  Amman   34    Male   700.0         3.0
# ...

# %%
data['new_salary']=data['salary']+50
data
# Out:
#       id  Education  JoiningYear   City  Age  Gender  salary  Experience  \
# 0   8675  Bachelors         2017  Amman   34    Male   500.0         0.0
# 1   1531  Bachelors         2013  Irbid   28  Female   560.0         3.0
# 2   3028        PHD         2014  Irbid   38  Female  1000.0         2.0
# 3   2203    Masters         2016  Irbid   27  Female   800.0         5.0
# 4   4848    Masters         2017  Amman   24    Male   800.0         2.0
# 5   6877  Bachelors         2016  Amman   22    Male   550.0         0.0
# 6   2012  Bachelors         2015  Irbid   38    Male   550.0         0.0
# 7   8886  Bachelors         2016  Aqaba   34  Female   550.0         2.0
# 8   8741  Bachelors         2016  Amman   23    Male   550.0         1.0
# 9   6789    Masters         2017  Amman   37    Male   900.0         2.0
# 10  9872    Masters         2012  Amman   27    Male   800.0         5.0
# 11  2017  Bachelors         2016  Amman   34    Male   700.0         3.0
# ...
