# %% [markdown]
# <a href="https://colab.research.google.com/github/saqqad00-pixel/python-learning-journey/blob/main/Copy_of_Copy_of_saadaldain202510133.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("saad")
# Out:
# saad

# %%
Number1=1
number2=2
total=Number1+number2
print(total)
# Out:
# 3

# %% [markdown]
# ## Simple Calculator
#
# This section defines basic arithmetic operations and demonstrates their usage.

# %%
# Demonstrate the calculator functions
num1 = 10
num2 = 5

print(f"{num1} + {num2} = {add(num1, num2)}")
print(f"{num1} - {num2} = {subtract(num1, num2)}")
print(f"{num1} * {num2} = {multiply(num1, num2)}")
print(f"{num1} / {num2} = {divide(num1, num2)}")

# Test division by zero
num3 = 10
num4 = 0
print(f"{num3} / {num4} = {divide(num3, num4)}")
# Out:
# 10 + 5 = 15
# 10 - 5 = 5
# 10 * 5 = 50
# 10 / 5 = 2.0
# 10 / 0 = Error: Cannot divide by zero!

# %%
def add(x, y):
    """Adds two numbers."""
    return x + y

def subtract(x, y):
    """Subtracts two numbers."""
    return x - y

def multiply(x, y):
    """Multiplies two numbers."""
    return x * y

def divide(x, y):
    """Divides two numbers. Handles division by zero."""
    if y == 0:
        return "Error: Cannot divide by zero!"
    return x / y

print("Calculator functions defined.")
# Out:
# Calculator functions defined.

# %%
x=10
y=5
print (x)

number1=600
number2=300
number3=150
total=number1+number2+number3
print(total)
my_text="saadaldain"
mybool=True
print(type(my_text))
print(type(mybool))
print(type(number1))

print(type(number3))
print(type(total))
print(len(my_text))
print(my_text.upper)
print(my_text.lower)
# Out:
# 10
# 1050
# <class 'str'>
# <class 'bool'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# 10
# <built-in method upper of str object at 0x7aa1083a6170>
# <built-in method lower of str object at 0x7aa1083a6170>

# %%
x=5<20

print(x)
print(type(x))

y=1010>2010
print(y)
print(type(y))

#
# Out:
# True
# <class 'bool'>
# False
# <class 'bool'>

# %%
students=["saad","saadaldain",]
print(students)
print(type(students))
print(len(students))
# Out:
# ['saad', 'saadaldain']
# <class 'list'>
# 2

# %%
team=["sam"],["saad"],["saadaldain"],["samer"],["saeed"]
print(team)
print(type(team))
print(len(team))
print(team[0:3])
print(team[:])
print(team[0:4])
print(team[0:3:2])
# Out:
# (['sam'], ['saad'], ['saadaldain'], ['samer'], ['saeed'])
# <class 'tuple'>
# 5
# (['sam'], ['saad'], ['saadaldain'])
# (['sam'], ['saad'], ['saadaldain'], ['samer'], ['saeed'])
# (['sam'], ['saad'], ['saadaldain'], ['samer'])
# (['sam'], ['saadaldain'])
